# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
from PIL import Image

# %%
# Load dataset
df = pd.read_excel("3 year 21-22-23 SAC Agg.xlsx")

df.head()
df.columns
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 153 entries, 0 to 152
# Data columns (total 31 columns):
#  #   Column                                                  Non-Null Count  Dtype
# ---  ------                                                  --------------  -----
#  0   State                                                   153 non-null    str
#  1   Year                                                    153 non-null    int64
#  2   Organizations                                           153 non-null    int64
#  3   Intake - Relinquished By Owner Total-Feline             153 non-null    int64
#  4   Intake - Stray At Large Total-Feline                    153 non-null    int64
#  5   Intake - Transferred In Total-Feline                    153 non-null    int64
#  6   Intake - Owner Intended Euthanasia Total-Feline         153 non-null    int64
#  7   Intakes - Other Intakes Total-Feline                    153 non-null    int64
#  8   Live Outcome - Adoption Total-Feline                    153 non-null    int64
#  9   Live Outcome - Returned To Owner Total-Feline           153 non-null    int64
#  10  Live Outcome - Returned To Field Total-Feline           153 non-null    int64
#  11  Live Outcome - Transferred Out Total-Feline             153 non-null    int64
#  12  Live outcome - Other Live Outcome Total-Feline          153 non-null    int64
#  13  Other Outcome - Died In Care Total-Feline               153 non-null    int64
#  14  Other Outcome - Lost In Care Total-Feline               153 non-null    int64
#  15  Other Outcome - Owner Intended Euthanasia Total-Feline  153 non-null    int64
#  16  Other Outcome - Shelter Euthanasia Total-Feline         153 non-null    int64
#  17  Intake - Relinquished By Owner Total-Canine             153 non-null    int64
#  18  Intake - Stray At Large Total-Canine                    153 non-null    int64
#  19  Intake - Transferred In Total-Canine                    153 non-null    int64
#  20  Intake - Owner Intended Euthanasia Total-Canine         153 non-null    int64
#  21  Intakes - Other Intakes Total-Canine                    153 non-null    int64
#  22  Live Outcome - Adoption Total-Canine                    153 non-null    int64
#  23  Live Outcome - Returned To Owner Total-Canine           153 non-null    int64
#  24  Live Outcome - Returned To Field Total-Canine           153 non-null    int64
#  25  Live Outcome - Transferred Out Total-Canine             153 non-null    int64
#  26  Live outcome - Other Live Outcome Total-Canine          153 non-null    int64
#  27  Other Outcome - Died In Care Total-Canine               153 non-null    int64
#  28  Other Outcome - Lost In Care Total-Canine               153 non-null    int64
#  29  Other Outcome - Owner Intended Euthanasia Total-Canine  153 non-null    int64
#  30  Other Outcome - Shelter Euthanasia Total-Canine         153 non-null    int64
# dtypes: int64(30), str(1)
# memory usage: 37.2 KB

# %%
# List live outcome columns
feline_cols = [
    "Live Outcome - Adoption Total-Feline",
    "Live Outcome - Returned To Owner Total-Feline",
    "Live Outcome - Returned To Field Total-Feline",
    "Live Outcome - Transferred Out Total-Feline",
    "Live outcome - Other Live Outcome Total-Feline"
]

canine_cols = [
    "Live Outcome - Adoption Total-Canine",
    "Live Outcome - Returned To Owner Total-Canine",
    "Live Outcome - Returned To Field Total-Canine",
    "Live Outcome - Transferred Out Total-Canine",
    "Live outcome - Other Live Outcome Total-Canine"
]

# Total intake
df["Total Live Outcome"] = df[feline_cols + canine_cols].sum(axis=1)

# %%
import sys
# !{sys.executable} -m pip install -U kaleido
# Out:
# Requirement already satisfied: kaleido in ./venv/lib/python3.14/site-packages (1.2.0)
# Requirement already satisfied: choreographer>=1.1.1 in ./venv/lib/python3.14/site-packages (from kaleido) (1.2.1)
# Requirement already satisfied: logistro>=1.0.8 in ./venv/lib/python3.14/site-packages (from kaleido) (2.0.1)
# Requirement already satisfied: orjson>=3.10.15 in ./venv/lib/python3.14/site-packages (from kaleido) (3.11.8)
# Requirement already satisfied: packaging in ./venv/lib/python3.14/site-packages (from kaleido) (26.0)
# Requirement already satisfied: pytest-timeout>=2.4.0 in ./venv/lib/python3.14/site-packages (from kaleido) (2.4.0)
# Requirement already satisfied: simplejson>=3.19.3 in ./venv/lib/python3.14/site-packages (from choreographer>=1.1.1->kaleido) (4.1.0)
# Requirement already satisfied: pytest>=7.0.0 in ./venv/lib/python3.14/site-packages (from pytest-timeout>=2.4.0->kaleido) (9.0.3)
# Requirement already satisfied: iniconfig>=1.0.1 in ./venv/lib/python3.14/site-packages (from pytest>=7.0.0->pytest-timeout>=2.4.0->kaleido) (2.3.0)
# Requirement already satisfied: pluggy<2,>=1.5 in ./venv/lib/python3.14/site-packages (from pytest>=7.0.0->pytest-timeout>=2.4.0->kaleido) (1.6.0)
# Requirement already satisfied: pygments>=2.7.2 in ./venv/lib/python3.14/site-packages (from pytest>=7.0.0->pytest-timeout>=2.4.0->kaleido) (2.20.0)
#
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip

# %%
vmin = df["Total Live Outcome"].min()
vmax = df["Total Live Outcome"].max()

years = [2021, 2022, 2023]

for year in years:
    df_year = df[df["Year"] == year]

    fig = px.choropleth(
        df_year,
        locations="State",       
        locationmode="USA-states",
        color="Total Live Outcome",
        scope="usa",
        range_color=(vmin, vmax), 
        color_continuous_scale="Cividis",
        title=f"Total Live Outcome by State ({year})",
    )

    fig.update_traces(marker_line_color="black", marker_line_width=0.5)

    fig.update_layout(
        coloraxis_colorbar=dict(
            title="Total Live Outcome",
            tickformat=","
        )
    )

    fig.write_image(f"Heat_maps/live_outcome_map_{year}.png", width=1200, height=700)

# %%
# make gif
years = [2021, 2022, 2023]
 
frames = []
for year in years:
    img = Image.open(f"Heat_maps/live_outcome_map_{year}.png")
    frames.append(img)

frames[0].save(
    "Heat_maps/animal_live_outcome.gif",
    save_all=True,
    append_images=frames[1:],
    duration=1500,  # 1.5 seconds per frame
    loop=0
)
